# %%
import os
import cv2
import numpy as np
from PIL import Image

# %%
# Initialize empty lists to store image data and corresponding labels
data = []
labels = []

# Process Basal Cell Carcinoma images
Basal = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Basal_cell_carcinoma/train/")
for a in Basal:
    try:
        # Read and resize image
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Basal_cell_carcinoma/train/" + a)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(0)  # Assign label 0 for Basal Cell Carcinoma
    except AttributeError:
        print("")

# Process Melanoma images
Melanoma = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Melanoma/train/")
for b in Melanoma:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Melanoma/train/" + b)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(1)  # Assign label 1 for Melanoma
    except AttributeError:
        print("")

# Process Nevus images
Nevus = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Nevus/train/")
for c in Nevus:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Nevus/train/" + c)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(2)  # Assign label 2 for Nevus
    except AttributeError:
        print("")

# Process Benign Keratosis images
Benign_K = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/benign_keratosis/train/")
for d in Benign_K:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/benign_keratosis/train/" + d)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(3)  # Assign label 3 for Benign Keratosis
    except AttributeError:
        print("")

# Process images with no cancer
No_cancer = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/no_cancer/train/")
for e in No_cancer:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/no_cancer/train/" + e)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(4)  # Assign label 4 for No Cancer
    except AttributeError:
        print("")

# Convert features and labels into arrays
feats = np.array(data)
labels = np.array(labels)

# %%
# Save features and labels for later re-use
np.save("/content/drive/My Drive/skin_cancer_dataset/check_points/feats_train", feats)
np.save("/content/drive/My Drive/skin_cancer_dataset/check_points/labels_train", labels)

# %%
# Initialize empty lists to store image data and corresponding labels
data = []
labels = []

# Process Basal Cell Carcinoma images
Basal = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Basal_cell_carcinoma/test/")
for a in Basal:
    try:
        # Read and resize image
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Basal_cell_carcinoma/test/" + a)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(0)  # Assign label 0 for Basal Cell Carcinoma
    except AttributeError:
        print("")

# Process Melanoma images
Melanoma = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Melanoma/test/")
for b in Melanoma:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Melanoma/test/" + b)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(1)  # Assign label 1 for Melanoma
    except AttributeError:
        print("")

# Process Nevus images
Nevus = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Nevus/test/")
for c in Nevus:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/Nevus/test/" + c)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(2)  # Assign label 2 for Nevus
    except AttributeError:
        print("")

# Process Benign Keratosis images
Benign_K = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/benign_keratosis/test/")
for d in Benign_K:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/benign_keratosis/test/" + d)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(3)  # Assign label 3 for Benign Keratosis
    except AttributeError:
        print("")

# Process images with no cancer
No_cancer = os.listdir("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/no_cancer/test/")
for e in No_cancer:
    try:
        image = cv2.imread("/content/drive/My Drive/skin_cancer_dataset/ISIC_Training_Input/no_cancer/test/" + e)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((224, 224))
        data.append(np.array(size_image))
        labels.append(4)  # Assign label 4 for No Cancer
    except AttributeError:
        print("")

# Convert features and labels into arrays
feats = np.array(data)
labels = np.array(labels)

# %%
# Save features and labels for later re-use
np.save("/content/drive/My Drive/skin_cancer_dataset/check_points/feats_test", feats)
np.save("/content/drive/My Drive/skin_cancer_dataset/check_points/labels_test", labels)
